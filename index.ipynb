# %% [markdown]
# # Objectives

# %% [markdown]
#  Develop a machine learning model that can accurately classify breast tumors as malignant or benign based on the provided features.

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd

# Define the column names based on the dataset description
columns = [
    'ID', 'Diagnosis',
    'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
    'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
    'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
    'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se', 'fractal_dimension_se',
    'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst',
    'compactness_worst', 'concavity_worst', 'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'
]

# Step 1: Read the data file into a DataFrame with the correct delimiter
df = pd.read_csv('wdbc.data', delimiter=',', header=None)

# Step 2: Assign the column names to the DataFrame
df.columns = columns

# Step 3: Display the first few rows of the dataframe to verify
df.head()
# Out:
#          ID Diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# import pandas as pd
# import os

# # Define the column names based on the dataset description
# columns = [
#     'ID', 'Diagnosis',
#     'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
#     'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#     'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#     'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se', 'fractal_dimension_se',
#     'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst',
#     'compactness_worst', 'concavity_worst', 'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'
# ]

# # Path to the data file
# file_path = 'wdbc.data'

# # Check if the file exists
# if not os.path.exists(file_path):
#     raise FileNotFoundError(f"The file {file_path} does not exist.")

# # Read the data file into a DataFrame
# df = pd.read_csv(file_path, header=None, names=columns)

# # Display the first few rows of the dataframe to verify
# print(df.head())

# %%
df.columns
# Out:
# Index(['ID', 'Diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ID: This could refer to a unique identifier for each patient or sample in the dataset.
#
# Diagnosis: This likely indicates the diagnosis of each sample, such as whether it is classified as malignant or benign.
#
# radius_mean: The average radius of the detected tumor cells.
#
# texture_mean: The average texture (variation in grayscale intensity) of the tumor cells.
#
# perimeter_mean: The average perimeter (the length of the boundary) of the tumor cells.
#
# area_mean: The average area (size) of the tumor cells.
#
# smoothness_mean: The average smoothness of the boundary of the tumor cells.
#
# compactness_mean: The average compactness of the tumor cells, which can be a measure of how closely packed the cells are.
#
# concavity_mean: The average severity of concave portions of the contour of the tumor cells.
#
# concave_points_mean: The average number of concave portions of the contour of the tumor cells.
#
# symmetry_mean: The average symmetry of the tumor cells.
#
# fractal_dimension_mean: The average fractal dimension, which is a measure of how complex the boundary of the tumor cells is.
#
# radius_se: The standard error of the radius of the tumor cells.
#
# texture_se: The standard error of the texture of the tumor cells.
#
# perimeter_se: The standard error of the perimeter of the tumor cells.
#
# area_se: The standard error of the area of the tumor cells.
#
# smoothness_se: The standard error of the smoothness of the boundary of the tumor cells.
#
# compactness_se: The standard error of the compactness of the tumor cells.
#
# concavity_se: The standard error of the severity of concave portions of the contour of the tumor cells.
#
# concave_points_se: The standard error of the number of concave portions of the contour of the tumor cells.
#
# symmetry_se: The standard error of the symmetry of the tumor cells.
#
# fractal_dimension_se: The standard error of the fractal dimension of the tumor cells.
#
# radius_worst: The "worst" or largest radius among the tumor cells.
#
# texture_worst: The "worst" or most intense texture among the tumor cells.
#
# perimeter_worst: The "worst" or largest perimeter among the tumor cells.
#
# area_worst: The "worst" or largest area among the tumor cells.
#
# smoothness_worst: The "worst" or least smooth boundary among the tumor cells.
#
# compactness_worst: The "worst" or highest compactness among the tumor cells.
#
# concavity_worst: The "worst" or highest severity of concave portions of the contour among the tumor cells.
#
# concave_points_worst: The "worst" or highest number of concave portions of the contour among the tumor cells.
#
# symmetry_worst: The "worst" or least symmetric tumor cells.
#
# fractal_dimension_worst: The "worst" or highest fractal dimension among the tumor cells.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       569 non-null    int64
#  1   Diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                         0
# Diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                  ID  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
# Target Variable:
df.Diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: Diagnosis, dtype: int64

# %%
df['Diagnosis'] = df['Diagnosis'].apply(lambda val: 1 if val == 'M' else 0)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Create a bar plot for the 'Diagnosis' column
plt.figure(figsize=(8, 6))
sns.countplot(x='Diagnosis', data=df, palette='Set1')

# Add title and labels
plt.title('Distribution of Diagnosis (Malignant vs. Benign)', fontsize=16)
plt.xlabel('Diagnosis', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the plot
plt.show()

# %% [markdown]
# Most tumor cells are diagnosed as Benign.The dataset has a noticeable class imbalance, with benign cases being more prevalent than malignant cases.This imbalance is crucial to note because it can affect the performance of machine learning models, often leading to models that are biased towards the more frequent class (benign).

# %%
# # Import necessary libraries
# import pandas as pd
# import matplotlib.pyplot as plt

# # Load the dataset (replace 'your_dataset.csv' with the actual file path)
# data = pd.read_csv('your_dataset.csv')

# List of numerical columns
numerical_columns = [
    'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
    'compactness_mean', 'concavity_mean', 'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
    'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
    'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se', 'fractal_dimension_se',
    'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst',
    'compactness_worst', 'concavity_worst', 'concave_points_worst', 'symmetry_worst', 'fractal_dimension_worst'
]

# # Set up the matplotlib figure and axis
# fig, axes = plt.subplots(len(numerical_columns) // 3 + 1, 3, figsize=(15, 60))
# axes = axes.flatten()
# Calculate the number of rows needed
num_plots = len(numerical_columns)
num_cols = 3
num_rows = (num_plots + num_cols - 1) // num_cols

# Set up the matplotlib figure and axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))
axes = axes.flatten()

# Loop through numerical columns and plot histograms
for i, col in enumerate(numerical_columns):
    ax = axes[i]
    df[col].hist(bins=30, ax=ax)
    ax.set_title(col)
    ax.set_xlabel(col)
    ax.set_ylabel('Frequency')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the number of rows needed
num_plots = len(numerical_columns)
num_cols = 3
num_rows = (num_plots + num_cols - 1) // num_cols

# Set up the matplotlib figure and axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))
axes = axes.flatten()

# Loop through numerical columns and plot box plots
for i, col in enumerate(numerical_columns):
    ax = axes[i]
    sns.boxplot(x='Diagnosis', y=col, data=df, ax=ax, palette='Set2')
    ax.set_title(col)
    ax.set_xlabel('Diagnosis')
    ax.set_ylabel(col)

# Remove empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#                                ID  Diagnosis  radius_mean  texture_mean  \
# ID                       1.000000   0.039769     0.074626      0.099770
# Diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave_points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
fig, ax = plt.subplots(figsize=(20,15)) 
sns.heatmap(df.corr(),ax=ax,annot=True,linewidth=.5)
# Out:
# <Axes: >

# %% [markdown]
#     the radius, parameter and area are highly correlated as expected from their relation so from these we will use anyone of them
#     compactness_mean, concavity_mean and concavepoint_mean are highly correlated so we will use compactness_mean from here
#     so selected Parameter for use is perimeter_mean, texture_mean, compactness_mean, symmetry_mean

# %%
df.describe()
# Out:
#                  ID   Diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  5.690000e+02  569.000000   569.000000    569.000000      569.000000
# mean   3.037183e+07    0.372583    14.127292     19.289649       91.969033
# std    1.250206e+08    0.483918     3.524049      4.301036       24.298981
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       569.000000        569.000000      569.000000
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
def normalize_data_frame(data_frame):
    """
    Purpose
    ----------
    Function created to normalize data set.
    Intializes an empty data frame which will normalize all columns that
    have at > 10 unique values (chosen arbitrarily since target columns
    will have classes < 10) and append the non-float types.
    Application can vary significantly for different data set, use with caution
    or modify accordingly.

    Parameters
    ----------
    * data_frame: 	Name of pandas.dataframe

    Returns
    ----------
    * data_frame_norm:	Normalized dataframe values ranging (0, 1)
    """
    data_frame_norm = pd.DataFrame()
    for col in data_frame:
        if ((len(np.unique(data_frame[col])) > 10) & (data_frame[col].dtype != 'object')):
            data_frame_norm[col]=((data_frame[col] - data_frame[col].min()) /
                                  (data_frame[col].max() - data_frame[col].min()))
        else:
            data_frame_norm[col] = data_frame[col]
    return data_frame_norm

# %%
import numpy as np
breast_cancer_norm = normalize_data_frame(df)

# %%
breast_cancer_norm.describe()
# Out:
#                ID   Diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  569.000000  569.000000   569.000000    569.000000      569.000000
# mean     0.033318    0.372583     0.338222      0.323965        0.332935
# std      0.137187    0.483918     0.166787      0.145453        0.167915
# min      0.000000    0.000000     0.000000      0.000000        0.000000
# 25%      0.000944    0.000000     0.223342      0.218465        0.216847
# 50%      0.000985    0.000000     0.302381      0.308759        0.293345
# 75%      0.009661    1.000000     0.416442      0.408860        0.416765
# max      1.000000    1.000000     1.000000      1.000000        1.000000
#
#         area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count  569.000000       569.000000        569.000000      569.000000
# mean     0.216920         0.394785          0.260601        0.208058
# std      0.149274         0.126967          0.161992        0.186785
# ...

# %%
# Calculate the number of rows needed
num_plots = len(numerical_columns)
num_cols = 3
num_rows = (num_plots + num_cols - 1) // num_cols

# Set up the matplotlib figure and axes
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))
axes = axes.flatten()

# Loop through numerical columns and plot box plots
for i, col in enumerate(numerical_columns):
    ax = axes[i]
    sns.boxplot(x='Diagnosis', y=col, data=breast_cancer_norm, ax=ax, palette='Set2')
    ax.set_title(col)
    ax.set_xlabel('Diagnosis')
    ax.set_ylabel(col)

# Remove empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
#correlation map
f,ax = plt.subplots(figsize=(18, 18))
#cmap = sns.diverging_palette( 240 , 10 , as_cmap = True )
sns.heatmap(df.corr(), cmap='Blues',annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.xticks(fontsize=11,rotation=70)
plt.show()

# %% [markdown]
# ID
# Diagnosis
# radius_mean
# texture_mean
# smoothness_mean
# compactness_mean
# concavity_mean
# concave_points_mean
# symmetry_mean
# fractal_dimension_mean
# radius_se
# texture_se
# smoothness_se
# compactness_se
# concavity_se
# concave_points_se
# symmetry_se
# fractal_dimension_se
# radius_worst
# texture_worst
# smoothness_worst
# compactness_worst
# concavity_worst
# symmetry_worst
# fractal_dimension_worst

# %%
# import pandas as pd

# # Assuming your DataFrame is named df
# # Drop the specified columns
# df.drop(columns=['ID','perimeter_mean', 'area_mean', 'perimeter_worst', 'area_worst', 'concave_points_worst', 'perimeter_se', 'area_se'], inplace=True)

# # Print the first few rows of the modified DataFrame to confirm the columns were dropped
# df.head()

# %%
# # creating features and label 
# X = df.drop('Diagnosis', axis = 1)
# y = df['Diagnosis']

# %%
# # splitting data into training and test set

# from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
# # scaling data

# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()

# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)

# %%
# # fitting data to model

# from sklearn.linear_model import LogisticRegression

# log_reg = LogisticRegression()
# log_reg.fit(X_train, y_train)

# %%
# # model predictions

# y_pred = log_reg.predict(X_test)
